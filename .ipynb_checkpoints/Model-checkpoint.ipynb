# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
# Out:
# Using TensorFlow backend.

# %%
columns = ['id','daytime','power']

# %%
pd.read_csv?

# %%
data1 = pd.read_csv('File1.txt',sep = ' ',names = columns)

# %%
data1.head(5)
# Out:
#      id  daytime  power
# 0  1392    19503  0.140
# 1  1392    19504  0.138
# 2  1392    19505  0.140
# 3  1392    19506  0.145
# 4  1392    19507  0.145

# %%
data1['day']=data1['daytime'][:]
data1['time'] = data1['daytime'][:]

# %%
data1.head(5)
# Out:
#      id  daytime  power    day   time
# 0  1392    19503  0.140  19503  19503
# 1  1392    19504  0.138  19504  19504
# 2  1392    19505  0.140  19505  19505
# 3  1392    19506  0.145  19506  19506
# 4  1392    19507  0.145  19507  19507

# %%
data1['day'] = data1['day']/100
data1['day'] = np.int64(data1['day'])
data1['time']= data1['time']%100
data1['time'] = np.int64(data1['time'])

# %%
data1.drop(columns= ['daytime'])
# Out:
#             id  power  day  time
# 0         1392  0.140  195     3
# 1         1392  0.138  195     4
# 2         1392  0.140  195     5
# 3         1392  0.145  195     6
# 4         1392  0.145  195     7
# 5         1392  0.157  195     1
# 6         1392  0.144  195     2
# 7         1392  0.128  197    24
# 8         1392  0.142  197    25
# 9         1392  0.145  197    26
# 10        1392  0.149  197    27
# 11        1392  0.131  197    28
# 12        1392  0.130  197    29
# 13        1392  0.130  197    30
# 14        1392  0.152  197    31
# 15        1392  0.143  197    32
# 16        1392  0.130  197    33
# 17        1392  0.132  197    34
# 18        1392  0.169  197    35
# 19        1392  0.254  197    36
# 20        1392  0.231  197    37
# 21        1392  0.371  197    38
# 22        1392  0.266  197    39
# 23        1392  0.253  197    40
# 24        1392  0.579  197    41
# 25        1392  0.229  197    42
# 26        1392  0.225  197    43
# ...

# %%
data1.shape
# Out:
# (24465838, 5)

# %%
customer = {}
for ix in range(data1.shape[0]):
    if data1['id'][ix] not in customer:
        customer[data1['id'][ix]] = data1['power'][ix]
    else:
        customer[data1['id'][ix]] += data1['power'][ix]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-68-eeb98b598780> in <module>
#       2 customer = {}
#       3 for ix in range(data1.shape[0]):
# ----> 4     if data1['id'][ix] not in customer:
#       5         customer[data1['id'][ix]] = data1['power'][ix]
#       6     else:
#
# c:\programdata\anaconda3\envs\tensorflow\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# KeyboardInterrupt:

# %%
np.min(data1['day'])
# Out:
# 195

# %%
np.max(data1['day'])
# Out:
# 730

# %%
unique_days = np.unique(data1['day'])

# %%
print (len(unique_days))
# Out:
# 536

# %%
unique_days
# Out:
# array([195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207,
#        208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220,
#        221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233,
#        234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246,
#        247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259,
#        260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272,
#        273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285,
#        286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298,
#        299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311,
#        312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324,
#        325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336, 337,
#        338, 339, 340, 341, 342, 343, 344, 345, 346, 347, 348, 349, 350,
#        351, 352, 353, 354, 355, 356, 357, 358, 359, 360, 361, 362, 363,
# ...

# %%
data1 = data1[(data1.day<223) & (data1.day>=195)]

# %%
print (np.unique(data1['id']))
# Out:
# [1000 1001 1002 1003 1004 1005 1006 1007 1008 1009 1010 1011 1012 1013
#  1014 1015 1016 1017 1018 1019 1020 1021 1022 1023 1024 1025 1026 1027
#  1028 1029 1030 1031 1032 1033 1034 1035 1036 1037 1038 1039 1040 1041
#  1042 1043 1044 1045 1046 1047 1048 1049 1050 1051 1052 1053 1054 1055
#  1056 1057 1058 1059 1060 1061 1062 1063 1064 1065 1066 1067 1068 1069
#  1070 1071 1072 1073 1074 1075 1076 1077 1078 1079 1080 1081 1082 1083
#  1084 1085 1086 1087 1088 1089 1090 1091 1092 1093 1094 1095 1096 1097
#  1098 1099 1100 1101 1102 1103 1104 1105 1106 1107 1108 1109 1110 1111
#  1112 1113 1115 1116 1117 1118 1119 1120 1121 1122 1123 1124 1125 1126
#  1127 1128 1129 1130 1131 1132 1133 1134 1135 1136 1137 1138 1139 1140
#  1141 1142 1143 1144 1145 1146 1147 1148 1149 1150 1151 1152 1153 1154
#  1155 1156 1157 1158 1159 1160 1161 1162 1163 1164 1165 1166 1167 1168
#  1169 1170 1171 1172 1173 1174 1175 1176 1177 1178 1179 1180 1181 1182
# ...

# %%
data1 = data1.drop(columns = ['daytime'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-154-28bb68228fb0> in <module>
# ----> 1 data1 = data1.drop(columns = ['daytime'])
#
# c:\programdata\anaconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3928                                            index=index, columns=columns,
#    3929                                            level=level, inplace=inplace,
# -> 3930                                            errors=errors)
#    3931
#    3932     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# c:\programdata\anaconda3\envs\tensorflow\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3768         for axis, labels in axes.items():
#    3769             if labels is not None:
# ...

# %%
data1.shape
# Out:
# (1315392, 4)

# %%
data1['id'][]
# Out:
# 1392

# %%
from collections import Counter

# %%
count = 0
temp = data1['id'].values.tolist()
no_of_occur = Counter(temp)
for i in no_of_occur.keys():
    print (i,no_of_occur[i])
# Out:
# 1392 1344
# 1951 1344
# 1491 1344
# 1194 1344
# 1804 1344
# 1048 1344
# 1802 1344
# 1287 1344
# 1529 1344
# 1463 1344
# 1860 1344
# 1922 1344
# 1334 1344
# 1604 1344
# 1042 1344
# 1494 1344
# 1078 1344
# 1984 1344
# 1083 1344
# 1978 1344
# 1481 1344
# 1524 1344
# 1637 1344
# 1783 1344
# 1539 1344
# 1777 1344
# 1518 1344
# 1698 1344
# 1094 1344
# 1302 1344
# 1824 1344
# 1957 1344
# 1020 1344
# 1502 1344
# 1625 1344
# 1817 1344
# 1196 1344
# 1320 1344
# 1105 1344
# 1870 1344
# 1224 1344
# 1452 1344
# 1044 1344
# 1920 1344
# 1781 1344
# 1139 1344
# 1981 1344
# 1340 1344
# 1742 1344
# 1549 1344
# 1189 1344
# 1362 1344
# 1336 1344
# 1106 1344
# 1891 1344
# 1182 1344
# 1532 1344
# 1428 1344
# 1264 1344
# 1087 1344
# 1014 1344
# 1348 1344
# 1948 1344
# 1944 1344
# 1073 1344
# 1772 1344
# 1077 1344
# 1745 1344
# 1592 1344
# 1292 1344
# 1295 1344
# 1941 1344
# 1503 1344
# 1008 1344
# 1052 1344
# 1835 1344
# 1306 1344
# 1823 1344
# 1398 1344
# 1528 1344
# 1123 1344
# 1852 1344
# 1284 1344
# ...

# %%
no_of_occur
# Out:
# Counter({1392: 1344,
#          1951: 1344,
#          1491: 1344,
#          1194: 1344,
#          1804: 1344,
#          1048: 1344,
#          1802: 1344,
#          1287: 1344,
#          1529: 1344,
#          1463: 1344,
#          1860: 1344,
#          1922: 1344,
#          1334: 1344,
#          1604: 1344,
#          1042: 1344,
#          1494: 1344,
#          1078: 1344,
#          1984: 1344,
#          1083: 1344,
#          1978: 1344,
#          1481: 1344,
#          1524: 1344,
#          1637: 1344,
#          1783: 1344,
#          1539: 1344,
#          1777: 1344,
#          1518: 1344,
#          1698: 1344,
#          1094: 1344,
#          1302: 1344,
#          1824: 1344,
#          1957: 1344,
#          1020: 1344,
#          1502: 1344,
#          1625: 1344,
#          1817: 1344,
#          1196: 1344,
#          1320: 1344,
#          1105: 1344,
#          1870: 1344,
#          1224: 1344,
#          1452: 1344,
#          1044: 1344,
# ...

# %% [markdown]
# ### ANN

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
def modelann():
    classifier = Sequential()
    classifier.add(Dense(output_dim = 5, init = 'uniform', activation = 'relu', input_dim = 28))
    classifier.add(Dense(output_dim = 1, init = 'uniform', activation = 'sigmoid'))
    
    classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    
    
    classifier.fit(X_train, y_train, batch_size = 10, nb_epoch = 100)
    
    y_pred = classifier.predict(X_test)
    y_pred = (y_pred > 0.5)

# %%
from sklearn.metrics import confusion_matrix
#cm = confusion_matrix(y_test, y_pred)
